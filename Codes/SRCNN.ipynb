# %% [markdown]
# # **Implementation of a Super-Resolution Convolutional Neural Network (SRNN)**
#
# ### References
# *   Image Super-Resolution using Deep Convolutional Neural Networks (paper)
# *   titu1994/Image-Super-Resolution (github)
#
# ### Steps
# *   Import datasets
# *   Create model
# *   Train model
# *   Evaluate model
# *   Show results

# %% [markdown]
# ## Import Datasets
